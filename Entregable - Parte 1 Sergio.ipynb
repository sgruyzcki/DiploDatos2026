# %% [markdown]
# #**Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# ##**Edición 2026**
#
# ---
# ## Trabajo práctico entregable - Parte 1
#
# ## VErsion Sergio GRuzycki

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd

import seaborn as sns

sns.set_context('talk')

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook 00 se explican los detalles de la siguiente sección.

# %%
url = 'https://raw.githubusercontent.com/DiploDatos/AnalisisyVisualizacion/master/sysarmy_survey_2026_processed.csv'
df = pd.read_csv(url)

# %%
df[:10]
# Out:
#                      work_province work_dedication  \
# 0                          Mendoza       Full-Time
# 1                         Santa Fe       Full-Time
# 2                     Buenos Aires       Full-Time
# 3  Ciudad Autónoma de Buenos Aires       Full-Time
# 4                            Jujuy       Full-Time
# 5                       Corrientes       Part-Time
# 6  Ciudad Autónoma de Buenos Aires       Full-Time
# 7                     Buenos Aires       Full-Time
# 8  Ciudad Autónoma de Buenos Aires       Full-Time
# 9  Ciudad Autónoma de Buenos Aires       Full-Time
#
#                                   work_contract_type  salary_monthly_BRUTO  \
# 0                          Staff (planta permanente)             3000000.0
# 1                                         Contractor             5000000.0
# 2  Tercerizado (trabajo a través de consultora o ...             4600000.0
# 3                          Staff (planta permanente)             7800000.0
# 4                                         Contractor             3500000.0
# 5                                         Contractor              400000.0
# 6                                         Contractor             8460000.0
# 7                                         Contractor             6400000.0
# 8                          Staff (planta permanente)             3000000.0
# 9                                         Contractor             6075000.0
#
#    salary_monthly_NETO                                      salary_in_usd  \
# 0            2400000.0  Mi sueldo está dolarizado (pero cobro en moned...
# 1            5000000.0                   Cobro todo el salario en dólares
# 2            3600000.0                 Cobro parte del salario en dólares
# 3            6000000.0                 Cobro parte del salario en dólares
# 4            3200000.0                   Cobro todo el salario en dólares
# 5             400000.0  Mi sueldo está dolarizado (pero cobro en moned...
# 6            7200000.0                   Cobro todo el salario en dólares
# 7            6400000.0                   Cobro todo el salario en dólares
# 8            2500000.0  Mi sueldo está dolarizado (pero cobro en moned...
# 9            6075000.0                   Cobro todo el salario en dólares
#
#             salary_last_dollar_value       salary_has_bonus  \
# 0                               1300                     No
# 1                               1400                     No
# 2                               1436                     No
# 3                               1470             3+ sueldos
# 4                                NaN                     No
# 5                               1450                     No
# 6                               6000  De uno a tres sueldos
# 7                                NaN                     No
# 8  no está dolarizado cobro en peso.     Menos de un sueldo
# 9                                NaN                     No
#
#          salary_bonus_tied_to salary_inflation_adjustment  ...  \
# 0      Performance individual                          No  ...
# 1              No recibo bono                          No  ...
# 2              No recibo bono                         Uno  ...
# 3       Mix de las anteriores                          No  ...
# 4              No recibo bono                          No  ...
# 5              No recibo bono                          No  ...
# 6  Performance de la compañía                         Uno  ...
# 7              No recibo bono                          No  ...
# 8  Performance de la compañía                 Más de tres  ...
# 9              No recibo bono                         Uno  ...
#
#    salary_on_call_duty_charge  \
# 0                         NaN
# 1                         NaN
# 2                         0.0
# 3                         NaN
# 4                         NaN
# 5                         0.0
# 6                         0.0
# 7                        10.0
# 8                         0.0
# 9                         NaN
#
#   aclara_el_numero_que_ingresaste_en_el_campo_anterior  \
# 0                                                NaN
# 1                                                NaN
# 2                      Porcentaje de mi sueldo bruto
# 3                                                NaN
# 4                                                NaN
# 5                      Porcentaje de mi sueldo bruto
# 6                                              Bruto
# 7                      Porcentaje de mi sueldo bruto
# 8                      Porcentaje de mi sueldo bruto
# 9                                                NaN
#
#    salir_o_seguir_contestando_sobre_estudios profile_age  profile_gender  \
# 0                                        NaN          45       Mujer Cis
# 1                                        NaN          50       Mujer Cis
# 2                          Terminar encuesta          36       Mujer Cis
# 3                                        NaN          60      Hombre Cis
# 4                                        NaN          29      Hombre Cis
# 5                          Terminar encuesta          22      Hombre Cis
# 6               Responder sobre mis estudios          47      Hombre Cis
# 7               Responder sobre mis estudios          29      Hombre Cis
# 8                          Terminar encuesta          40       Mujer Cis
# 9                                        NaN          30       Mujer Cis
#
#   profile_previous_survey                          company_best_companies  \
# 0                      Sí                                             NaN
# 1                      Sí                                             NaN
# 2                      Sí                                             NaN
# 3                      Sí                                             NaN
# 4                      Sí                                            Nose
# 5                      No  Devligths, Banco de Corrientes, Poder Judicial
# 6                      Sí     COELSA, Mercado Libre, Santander Tecnología
# 7                      Sí                                             NaN
# 8                      Sí                       Lemón, Salesforce y otras
# 9                      Sí                                             NaN
#
#   sueldo_dolarizado  work_seniority       _sal
# 0              True          Senior  3000000.0
# 1              True          Senior  5000000.0
# 2              True          Senior  4600000.0
# 3              True          Senior  7800000.0
# 4              True     Semi-Senior  3500000.0
# 5              True          Junior   400000.0
# 6              True          Senior  8460000.0
# 7              True     Semi-Senior  6400000.0
# 8              True     Semi-Senior  3000000.0
# 9              True          Senior  6075000.0
#
# [10 rows x 60 columns]

# %% [markdown]
# Cuando se vuelve a ejecutar la siguiente línea aparece la columna cured_progr....
# Porque en memoria queda ese campo incluido.

# %%
df.columns
# Out:
# Index(['work_province', 'work_dedication', 'work_contract_type',
#        'salary_monthly_BRUTO', 'salary_monthly_NETO', 'salary_in_usd',
#        'salary_last_dollar_value', 'salary_has_bonus', 'salary_bonus_tied_to',
#        'salary_inflation_adjustment', 'salary_percentage_inflation_adjustment',
#        'salary_month_last_inflation_adjustment',
#        'salary_comparison_last_semester', 'salary_benefit',
#        'salary_satisfaction', 'work_looking_for_job', 'profile_various_jobs',
#        'company_main_activity', 'profile_years_experience',
#        'work_years_in_company', 'work_years_in_current_position',
#        'work_people_in_charge_of', 'tools_platform',
#        'tools_programming_languages', 'tools_frameworks', 'tools_data_bases',
#        'tools_qa_testing', 'company_employee_number', 'work_work_modality',
#        'company_days_in_the_office', 'salary_inflation_policy',
#        'company_reduction_of_employees', 'company_recommended',
#        'tools_copilotchatgpt', 'vibe_coding', 'tools_ide_ia',
#        'algo_que_quieras_decir_sobre_tu_trabajo', 'salir_o_seguir_contestando',
#        'profile_studies_level', 'profile_studies_level_state',
#        'profile_career', 'profile_university',
#        'salir_o_seguir_contestando_sobre_las_guardias',
#        'company_max_interview', 'company_best_interview',
#        'profile_prefered_challenges', 'profile_hours_per_day',
#        'company_selection_process',
#        'salir_o_seguir_contestando_sobre_las_guardias1', 'work_on_call_duty',
#        'salary_on_call_duty_charge',
#        'aclara_el_numero_que_ingresaste_en_el_campo_anterior',
#        'salir_o_seguir_contestando_sobre_estudios', 'profile_age',
#        'profile_gender', 'profile_previous_survey', 'company_best_companies',
#        'sueldo_dolarizado', 'work_seniority', '_sal',
#        'cured_programming_languages'],
#       dtype='object')

# %% [markdown]
# # Ejercicio 1 - Análisis descriptivo
#
# Responder a la pregunta: **¿Cuáles son los lenguajes de programación asociados a los mejores salarios?**
#
# Para ello:
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en una sub-población. Por ejemplo, se pueden limitar a personas con un salario mayor que 300000 pesos, o a las personas que trabajan sólo en "Data Science", pero deben justificar su elección y reformular la pregunta inicial de ser necesario.
#   * Obtener una lista de los lenguajes de programación más populares. Decidir cuántos y cuáles seleccionan para incluir en el análisis.
#   * Para cada una de las otras columnas del punto anterior, elegir los rangos o valores seleccionan para incluir en el análisis.
# 3. Seleccionar métricas que ayuden a responder la pregunta, y los métodos para analizarlas. Elegir UNA de las siguientes opciones:
#   * Comparar las distribuciones de salario para cada lenguaje utilizando visualizaciones. Como la visualización es el producto final, debe ser clara y mostrar información relevante.
#   * Comparar medidas de estadística descriptiva sobre la distribución de salario para cada lenguaje. Sean creativos, la estadística descriptiva nos permite decir cosas como: "el 10% de los mejores sueldos los ganan, en su mayoría, programadores que saben kotlin!" (donde *mayoría* es un término medio engañoso que sólo significa más del 50%). Para comparar múltiples lenguajes, les recomendamos usar también visualizaciones.
#   * Comparar probabilidades. Por ejemplo: "Si sabés Python o Java, tenés un 30% más de chances de ganar arriba de 1000K".
#
# Si lo consideran necesario, realicen varias iteraciones. Es decir, si encuentran que las distribuciones de los lenguajes de programación que seleccionaron inicialmente no son muy diferentes, pueden re-hacer el análisis usando sólo los lenguajes de programación que son diferentes.

# %%
# complete here if you want to include more columns
relevant_columns = ['tools_programming_languages', 'salary_monthly_NETO']

# %% [markdown]
# ### Conteo de frecuencias de los lenguajes de programación
#
# La columna que contiene información sobre los lenguajes de programación utilizados es `tools_programming_languages`. Sus valores son strings con los lenguajes seleccionados separados por comas.

# %%
df.tools_programming_languages[:10]
# Out:
# 0    .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 1                   .NET, C#, HTML, Javascript, SQL
# 2                                           Go, SQL
# 3                         Ninguno de los anteriores
# 4                                Bash/Shell, Python
# 5                                      React Native
# 6    .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 7                              Go, PHP, Python, SQL
# 8                .NET, CSS, HTML, Javascript, Swift
# 9                         Ninguno de los anteriores
# Name: tools_programming_languages, dtype: object

# %%
df.salary_monthly_NETO[:12]
# Out:
# 0     2400000.0
# 1     5000000.0
# 2     3600000.0
# 3     6000000.0
# 4     3200000.0
# 5      400000.0
# 6     7200000.0
# 7     6400000.0
# 8     2500000.0
# 9     6075000.0
# 10    7900000.0
# 11    1800000.0
# Name: salary_monthly_NETO, dtype: float64

# %% [markdown]
# Las siguientes celdas de código separan estos lenguajes de programación y cuentan la frecuencia con la que aparecen.
#
# No es necesario entender este código en profundidad, aunque sí es un buen ejercicio.

# %%
# Convert the comma-separated string of languages to a list of string.
# Remove 'ninguno de los anteriores' option, spaces and training commas.
def split_languages(languages_str):
  if not isinstance(languages_str, str):
    return []
  # Remove 'other' option
  languages_str = languages_str.lower()\
    .replace('ninguno de los anteriores', '')
  # Split string into list of items
  # Remove spaces and commas for each item
  return [lang.strip().replace(',', '')
          for lang in languages_str.split()]

# Create a new column with the list of languages
df.loc[:, 'cured_programming_languages'] = df.tools_programming_languages\
    .apply(split_languages)
if 'cured_programming_languages' not in relevant_columns:
    relevant_columns.append('cured_programming_languages')

# Duplicate each row of df for each programming language
# mentioned in the response.
# We only include in df_lang the columns we are going to analyze later, so we
# don't duplicate innecesary information.
df_lang = df.cured_programming_languages\
    .apply(pd.Series).stack()\
    .reset_index(level=-1, drop=True).to_frame()\
    .join(df[relevant_columns])\
    .rename(columns={0: 'programming_language'})
# Horrible programming style! But a lot of data science code can be written with
# as concatenations of functions (pipelines), and there's no elegant way of
# doing that on Python.
df_lang[:30]
# Out:
#   programming_language                     tools_programming_languages  \
# 0                 .net  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 0                   c#  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 0                  css  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 0                   go  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 0                 html  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 0                 java  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 0           javascript  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 0                  sql  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 1                 .net                 .NET, C#, HTML, Javascript, SQL
# 1                   c#                 .NET, C#, HTML, Javascript, SQL
# 1                 html                 .NET, C#, HTML, Javascript, SQL
# 1           javascript                 .NET, C#, HTML, Javascript, SQL
# 1                  sql                 .NET, C#, HTML, Javascript, SQL
# 2                   go                                         Go, SQL
# 2                  sql                                         Go, SQL
# 4           bash/shell                              Bash/Shell, Python
# 4               python                              Bash/Shell, Python
# 5                react                                    React Native
# 5               native                                    React Native
# 6                 .net  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 6                   c#  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 6                  css  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 6                   go  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 6                 html  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 6                 java  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 6           javascript  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 6                  sql  .NET, C#, CSS, Go, HTML, Java, Javascript, SQL
# 7                   go                            Go, PHP, Python, SQL
# 7                  php                            Go, PHP, Python, SQL
# 7               python                            Go, PHP, Python, SQL
#
#    salary_monthly_NETO                       cured_programming_languages
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 0            2400000.0  [.net, c#, css, go, html, java, javascript, sql]
# 1            5000000.0                 [.net, c#, html, javascript, sql]
# 1            5000000.0                 [.net, c#, html, javascript, sql]
# 1            5000000.0                 [.net, c#, html, javascript, sql]
# 1            5000000.0                 [.net, c#, html, javascript, sql]
# 1            5000000.0                 [.net, c#, html, javascript, sql]
# 2            3600000.0                                         [go, sql]
# 2            3600000.0                                         [go, sql]
# 4            3200000.0                              [bash/shell, python]
# 4            3200000.0                              [bash/shell, python]
# 5             400000.0                                   [react, native]
# 5             400000.0                                   [react, native]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 6            7200000.0  [.net, c#, css, go, html, java, javascript, sql]
# 7            6400000.0                            [go, php, python, sql]
# 7            6400000.0                            [go, php, python, sql]
# 7            6400000.0                            [go, php, python, sql]

# %% [markdown]
# En la columna `programming_language` se encuentra cada lenguaje por separado. Notar que si una respuesta contenía 3 lenguajes, como `"HTML, Javascript, Python"`, la fila ha sido replicada 3 veces. Por ello, hay tres filas con índice 1.

# %%
language_count = df_lang.programming_language.value_counts()\
    .reset_index()\
    .rename(columns={'index': 'language', 'programming_language': 'frequency'})
language_count[:10]
# Out:
#     frequency  count
# 0         sql   2217
# 1  javascript   1860
# 2      python   1774
# 3        html   1385
# 4  typescript   1136
# 5         css    885
# 6  bash/shell    881
# 7        java    787
# 8         php    566
# 9        .net    530

# %% [markdown]
# ## Filtrado de lenguajes relevantes
#
# El siguiente código permite seleccionar sólo las filas donde el valor de la columna `programming_language` se encuentre en la lista `interesting_languages`.
#
# Cuando usamos el .sort_values se agregan al final los valores NaN

# %%
# Filter out languages that we want to exclude
# Complete here with your selected list.
interesting_languages = ["python"]
filtered_df_lang = df_lang[df_lang.programming_language.isin(interesting_languages)]
filtered_df_lang[:15].sort_values("salary_monthly_NETO", ascending=False)
# Out:
#    programming_language                        tools_programming_languages  \
# 28               python            C#, Javascript, Python, SQL, TypeScript
# 22               python                                       HTML, Python
# 7                python                               Go, PHP, Python, SQL
# 30               python                                             Python
# 35               python  Assembler, Bash/Shell, C, Groovy, Java, Javasc...
# 31               python                                             Python
# 4                python                                 Bash/Shell, Python
# 36               python                                        Python, SQL
# 32               python       Bash/Shell, CSS, HTML, Javascript, Python, R
# 20               python                                 COBOL, Python, SQL
# 19               python                                     Python, R, SQL
# 18               python  .NET, C#, HTML, Java, PHP, Python, SQL, Ningun...
# 24               python                  Python, Ninguno de los anteriores
# 15               python                                             Python
# 17               python      Java, Python, Scala, Domain Specific Language
#
#     salary_monthly_NETO                        cured_programming_languages
# 28           10000000.0          [c#, javascript, python, sql, typescript]
# 22            8000000.0                                     [html, python]
# 7             6400000.0                             [go, php, python, sql]
# 30            6000000.0                                           [python]
# 35            4500000.0  [assembler, bash/shell, c, groovy, java, javas...
# 31            3800000.0                                           [python]
# 4             3200000.0                               [bash/shell, python]
# 36            3110000.0                                      [python, sql]
# 32            3030000.0     [bash/shell, css, html, javascript, python, r]
# 20            3000000.0                               [cobol, python, sql]
# 19            3000000.0                                   [python, r, sql]
# 18            3000000.0           [.net, c#, html, java, php, python, sql]
# 24            3000000.0                                           [python]
# 15                  NaN                                           [python]
# 17                  NaN  [java, python, scala, domain, specific, language]

# %% [markdown]
# # Ejercicio 2 - Densidades y varias variables
#
# Responder a la pregunta general: **¿Que herramientas (prácticas y teóricas) són útiles para explorar la base, descubrir patrones, asociaciones?**
#
# Herramientas Teóricas:La estadística descriptiva con la Dispersión, los Cuantiles y Percentiles que permiten analizar la desviación y el ruido en los datos, además de entender desvíos y detectar casos extremos.
#
# Herramientas prácticas:En las herramientas prácticas tenemos Python como una de las más poderosas que nos permite ejecutar librerías como Pandas y Numpy. Para el análisis, transformación, presentación y graficación de los datos.
#
# Para ello considere (igual al ejercicio Anterior):
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en sub-poblaciones.

# %%
columnas = ['work_province', 'salary_monthly_NETO']

df_reducido = df[['work_province', 'salary_monthly_NETO']].copy()

df_reducido[:15]
# Out:
#                       work_province  salary_monthly_NETO
# 0                           Mendoza            2400000.0
# 1                          Santa Fe            5000000.0
# 2                      Buenos Aires            3600000.0
# 3   Ciudad Autónoma de Buenos Aires            6000000.0
# 4                             Jujuy            3200000.0
# 5                        Corrientes             400000.0
# 6   Ciudad Autónoma de Buenos Aires            7200000.0
# 7                      Buenos Aires            6400000.0
# 8   Ciudad Autónoma de Buenos Aires            2500000.0
# 9   Ciudad Autónoma de Buenos Aires            6075000.0
# 10  Ciudad Autónoma de Buenos Aires            7900000.0
# 11  Ciudad Autónoma de Buenos Aires            1800000.0
# 12                          Córdoba            9750000.0
# 13                     Buenos Aires                  NaN
# 14                         Santa Fe             600000.0

# %%
# Retiro todas las filas que tienen NaN y las que tienen cero

df_limpio = df_reducido.dropna(subset=['salary_monthly_NETO'])
df_limpio = df_limpio[df_limpio['salary_monthly_NETO'] != 0]
print("df_ reducido", df_reducido.count())
print("df_limpio ", df_limpio.count())
df_limpio[:15]
# Out:
# df_ reducido work_province          4939
# salary_monthly_NETO    4717
# dtype: int64
# df_limpio  work_province          4717
# salary_monthly_NETO    4717
# dtype: int64
#                       work_province  salary_monthly_NETO
# 0                           Mendoza            2400000.0
# 1                          Santa Fe            5000000.0
# 2                      Buenos Aires            3600000.0
# 3   Ciudad Autónoma de Buenos Aires            6000000.0
# 4                             Jujuy            3200000.0
# 5                        Corrientes             400000.0
# 6   Ciudad Autónoma de Buenos Aires            7200000.0
# 7                      Buenos Aires            6400000.0
# 8   Ciudad Autónoma de Buenos Aires            2500000.0
# 9   Ciudad Autónoma de Buenos Aires            6075000.0
# 10  Ciudad Autónoma de Buenos Aires            7900000.0
# 11  Ciudad Autónoma de Buenos Aires            1800000.0
# 12                          Córdoba            9750000.0
# 14                         Santa Fe             600000.0
# 16                     Buenos Aires            2600000.0

# %%
cuentas = df_limpio['work_province'].value_counts().reset_index()
cuentas.columns = ['work_province', 'cantidad_encuestados']

estadisticas = df_limpio.groupby('work_province')['salary_monthly_NETO'].agg(['mean', 'median']).reset_index()

tabla_final = cuentas.merge(estadisticas, on='work_province')

tabla_final = tabla_final.rename(columns={
    'mean': 'promedio_salarial',
    'median': 'mediana_salarial'
})
print(tabla_final)
# Out:
#                       work_province  cantidad_encuestados  promedio_salarial  \
# 0   Ciudad Autónoma de Buenos Aires                  2372       3.702574e+06
# 1                      Buenos Aires                  1001       4.058839e+06
# 2                           Córdoba                   429       3.489778e+06
# 3                          Santa Fe                   321       3.041810e+06
# 4                           Mendoza                   135       2.851517e+06
# 5                        Entre Ríos                    67       2.810688e+06
# 6                         Río Negro                    58       3.498340e+06
# 7                          Misiones                    41       2.820366e+06
# 8                           Tucumán                    38       2.373946e+06
# 9                           Neuquén                    38       3.540047e+06
# 10                            Chaco                    30       2.071959e+06
# 11                            Salta                    29       2.080709e+06
# 12                       Corrientes                    25       2.364940e+06
# 13                           Chubut                    24       2.960511e+06
# 14                            Jujuy                    21       3.018426e+06
# 15                         San Luis                    17       2.489893e+06
# 16                         La Rioja                    16       2.430303e+06
# 17                         San Juan                    14       2.741592e+06
# 18                         La Pampa                     9       3.094144e+06
# 19                 Tierra del Fuego                     9       3.170768e+06
# 20                       Santa Cruz                     7       1.945321e+06
# 21              Santiago del Estero                     6       2.061104e+06
# 22                          Formosa                     6       2.010333e+06
# 23                        Catamarca                     4       2.982500e+06
#
#     mediana_salarial
# 0          2900000.0
# 1          2700000.0
# 2          2868152.0
# 3          2597198.0
# 4          2400000.0
# 5          2200000.0
# 6          2603993.5
# 7          2700000.0
# 8          2182634.5
# 9          3450000.0
# 10         2050000.0
# 11         1744336.0
# 12         2258131.2
# 13         3100000.0
# 14         2412949.0
# 15         2200000.0
# 16         2200000.0
# 17         2515000.0
# 18         2900000.0
# 19         3100000.0
# 20         1696000.0
# 21         1925000.0
# 22         2008500.0
# 23         3015000.0

# %% [markdown]
# ## a) Densidad conjunta
#
# Que herramientas visuales y modelos puede utilizar para estudiar la distribución y comportamiento de sus datos?
#
# Elija tres variables numéricas y 2 variables categóricas. Visualice la base según varias de las variables elegidas. Puede describir de alguna forma el comportamiento de sus datos? Que herramientas utilizaría? Describa

# %% [markdown]
# ## b) Asociación
#
# * Necesitamos decidir si sacar o no la columna de salario bruto. Para hacer la encuesta más simple.
# ¿Existe una correlación entre el salario bruto y el neto? Que abordaje y medidas usaría

# %%
# 1. Limpieza: Filtrar filas con valores válidos (> 0) en ambas columnas
df_study = df[(df['salary_monthly_NETO'] > 0) &
              (df['salary_monthly_BRUTO'] > 0)].copy()

# 2. Eliminar Outliers extremos para que el gráfico sea legible
# Usamos el percentil 95 como límite superior
limit = df_study['salary_monthly_BRUTO'].quantile(0.95)
df_filtered = df_study[df_study['salary_monthly_BRUTO'] <= limit]

# 3. Calcular Correlación de Pearson
correlacion = df_filtered['salary_monthly_BRUTO'].corr(df_filtered['salary_monthly_NETO'])

print(f"Coeficiente de correlación de Pearson: {correlacion:.4f}")

# 4. Visualización
plt.figure(figsize=(10, 6))
sns.regplot(data=df_filtered,
            x='salary_monthly_BRUTO',
            y='salary_monthly_NETO',
            scatter_kws={'alpha':0.2}, # Transparencia para ver acumulación
            line_kws={'color':'red'})

plt.title(f'Correlación entre Salario Bruto y Neto (r = {correlacion:.2f})')
plt.xlabel('Salario Mensual BRUTO')
plt.ylabel('Salario Mensual NETO')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# Coeficiente de correlación de Pearson: 0.2121

# %%
mask_error = (df['salary_monthly_NETO'] > df['salary_monthly_BRUTO']) & \
             (df['salary_monthly_NETO'] > 0) & \
             (df['salary_monthly_BRUTO'] > 0)

df_errores = df.loc[mask_error, ['salary_monthly_BRUTO', 'salary_monthly_NETO']].copy()

cantidad_errores = len(df_errores)
porcentaje_errores = (cantidad_errores / len(df)) * 100

print(f"Cantidad de registros con Neto > Bruto: {cantidad_errores}")
print(f"Representan el {porcentaje_errores:.2f}% del total del dataset.")

if cantidad_errores > 0:
    print("\nMuestra de registros inconsistentes:")
    print(df_errores.head())
else:
    print("\n¡Buenas noticias! No se detectaron registros donde el Neto supere al Bruto.")
# Out:
# Cantidad de registros con Neto > Bruto: 161
# Representan el 3.26% del total del dataset.
#
# Muestra de registros inconsistentes:
#      salary_monthly_BRUTO  salary_monthly_NETO
# 36              2850000.0            3110000.0
# 49              4600000.0            5700000.0
# 114             5000000.0            6000000.0
# 137             2700000.0            3300000.0
# 223             6500000.0            7300000.0

# %% [markdown]
# ## c) Densidad condicional
#
# Estudie la distribución del salario según el nivel de estudio.
#
# Separe la población según el nivel de estudio (elija dos subpoblaciones numerosas) y grafique de manera comparativa ambos histogramas de la variable `'salary_monthly_NETO'`
# ¿Considera que ambas variables son independientes?
# ¿Qué analizaría al respecto?
#
# Calcule medidas de centralización y dispersión para cada subpoblación

# %% [markdown]
# ## d) Densidad Conjunta condicional
#
# Elija dos variables numéricas y una categórica.
# Estudie la dispersión (scatterplot) de las dos variables discriminando en color por la variable categórica (ayuda: hue en seaborn)
